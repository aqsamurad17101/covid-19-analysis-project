# %%
# ============================================
# COVID-19 DATA ANALYSIS PROJECT
# ============================================

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from pathlib import Path

import warnings
warnings.filterwarnings("ignore")

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %%
# Project directories

BASE_DIR = Path.cwd()

DATA_DIR = BASE_DIR / "data"
RAW_DATA_DIR = DATA_DIR / "raw"
PROCESSED_DATA_DIR = DATA_DIR / "processed"
VISUALIZATION_DIR = BASE_DIR / "visualizations"

# Create directories if they don't exist

RAW_DATA_DIR.mkdir(parents=True, exist_ok=True)
PROCESSED_DATA_DIR.mkdir(parents=True, exist_ok=True)
VISUALIZATION_DIR.mkdir(parents=True, exist_ok=True)

print("Project directories ready.")
# Out:
# Project directories ready.

# %%
import pandas as pd

url = "https://catalog.ourworldindata.org/garden/covid/latest/compact/compact.csv"

df = pd.read_csv(url)

# Save locally
df.to_csv("owid_covid_data.csv", index=False)

print("Dataset downloaded and saved successfully!")
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Dataset downloaded and saved successfully!
# Rows: 617667
# Columns: 61

# %%
df.head()
# Out:
#        country        date  total_cases  new_cases  new_cases_smoothed  \
# 0  Afghanistan  2020-01-01          NaN        NaN                 NaN
# 1  Afghanistan  2020-01-02          NaN        NaN                 NaN
# 2  Afghanistan  2020-01-03          NaN        NaN                 NaN
# 3  Afghanistan  2020-01-04          0.0        0.0                 NaN
# 4  Afghanistan  2020-01-05          0.0        0.0                 NaN
#
#    total_cases_per_million  new_cases_per_million  \
# 0                      NaN                    NaN
# 1                      NaN                    NaN
# 2                      NaN                    NaN
# 3                      0.0                    0.0
# 4                      0.0                    0.0
#
#    new_cases_smoothed_per_million  total_deaths  new_deaths  \
# 0                             NaN           NaN         NaN
# 1                             NaN           NaN         NaN
# ...

# %%
df.to_csv("owid_covid_data.csv", index=False)

print("Local copy saved successfully!")
# Out:
# Local copy saved successfully!

# %%
df.shape
# Out:
# (617667, 61)

# %%
df.head()
# Out:
#        country        date  total_cases  new_cases  new_cases_smoothed  \
# 0  Afghanistan  2020-01-01          NaN        NaN                 NaN
# 1  Afghanistan  2020-01-02          NaN        NaN                 NaN
# 2  Afghanistan  2020-01-03          NaN        NaN                 NaN
# 3  Afghanistan  2020-01-04          0.0        0.0                 NaN
# 4  Afghanistan  2020-01-05          0.0        0.0                 NaN
#
#    total_cases_per_million  new_cases_per_million  \
# 0                      NaN                    NaN
# 1                      NaN                    NaN
# 2                      NaN                    NaN
# 3                      0.0                    0.0
# 4                      0.0                    0.0
#
#    new_cases_smoothed_per_million  total_deaths  new_deaths  \
# 0                             NaN           NaN         NaN
# 1                             NaN           NaN         NaN
# ...

# %%
df.tail()
# Out:
#          country        date  total_cases  new_cases  new_cases_smoothed  \
# 617662  Zimbabwe  2026-08-26     266436.0        0.0                 0.0
# 617663  Zimbabwe  2026-08-27     266436.0        0.0                 0.0
# 617664  Zimbabwe  2026-08-28     266436.0        0.0                 0.0
# 617665  Zimbabwe  2026-08-29     266436.0        0.0                 0.0
# 617666  Zimbabwe  2026-08-30     266436.0        0.0                 0.0
#
#         total_cases_per_million  new_cases_per_million  \
# 617662                16580.682                    0.0
# 617663                16580.682                    0.0
# 617664                16580.682                    0.0
# 617665                16580.682                    0.0
# 617666                16580.682                    0.0
#
#         new_cases_smoothed_per_million  total_deaths  new_deaths  \
# 617662                             0.0        5740.0         0.0
# ...

# %%
print(df.columns.tolist())
# Out:
# ['country', 'date', 'total_cases', 'new_cases', 'new_cases_smoothed', 'total_cases_per_million', 'new_cases_per_million', 'new_cases_smoothed_per_million', 'total_deaths', 'new_deaths', 'new_deaths_smoothed', 'total_deaths_per_million', 'new_deaths_per_million', 'new_deaths_smoothed_per_million', 'excess_mortality', 'excess_mortality_cumulative', 'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative_per_million', 'hosp_patients', 'hosp_patients_per_million', 'weekly_hosp_admissions', 'weekly_hosp_admissions_per_million', 'icu_patients', 'icu_patients_per_million', 'weekly_icu_admissions', 'weekly_icu_admissions_per_million', 'stringency_index', 'reproduction_rate', 'total_tests', 'new_tests', 'total_tests_per_thousand', 'new_tests_per_thousand', 'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'positive_rate', 'tests_per_case', 'total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated', 'total_boosters', 'new_vaccinations', 'new_vaccinations_smoothed'
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 617667 entries, 0 to 617666
# Data columns (total 61 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   country                                     617667 non-null  object
#  1   date                                        617667 non-null  object
#  2   total_cases                                 605319 non-null  float64
#  3   new_cases                                   600623 non-null  float64
#  4   new_cases_smoothed                          599414 non-null  float64
#  5   total_cases_per_million                     605319 non-null  float64
#  6   new_cases_per_million                       600623 non-null  float64
#  7   new_cases_smoothed_per_million              599414 non-null  float64
#  8   total_deaths                                605319 non-null  float64
# ...

# %%
df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  \
# count  6.053190e+05  6.006230e+05        5.994140e+05
# mean   1.525363e+07  9.056902e+03        9.075189e+03
# std    7.742800e+07  1.088269e+05        9.295559e+04
# min    0.000000e+00  0.000000e+00        0.000000e+00
# 25%    1.105100e+04  0.000000e+00        0.000000e+00
# 50%    9.804100e+04  0.000000e+00        1.571428e+00
# 75%    1.197082e+06  2.500000e+01        1.175714e+02
# max    7.792774e+08  8.401906e+06        6.402033e+06
#
#        total_cases_per_million  new_cases_per_million  \
# count            605319.000000          600623.000000
# mean             140898.725384              84.903229
# std              180852.078187             907.958532
# min                   0.000000               0.000000
# 25%                4016.732400               0.000000
# 50%               59325.070000               0.000000
# 75%              223640.140000               2.551487
# ...

# %%
df.describe(include="all").T
# Out:
#                                                count unique         top  \
# country                                       617667    262    Zimbabwe
# date                                          617667   2434  2022-07-31
# total_cases                                 605319.0    NaN         NaN
# new_cases                                   600623.0    NaN         NaN
# new_cases_smoothed                          599414.0    NaN         NaN
# total_cases_per_million                     605319.0    NaN         NaN
# new_cases_per_million                       600623.0    NaN         NaN
# new_cases_smoothed_per_million              599414.0    NaN         NaN
# total_deaths                                605319.0    NaN         NaN
# new_deaths                                  601837.0    NaN         NaN
# new_deaths_smoothed                         600625.0    NaN         NaN
# total_deaths_per_million                    605319.0    NaN         NaN
# ...

# %%
df.dtypes
# Out:
# country                                        object
# date                                           object
# total_cases                                   float64
# new_cases                                     float64
# new_cases_smoothed                            float64
# total_cases_per_million                       float64
# new_cases_per_million                         float64
# new_cases_smoothed_per_million                float64
# total_deaths                                  float64
# new_deaths                                    float64
# new_deaths_smoothed                           float64
# total_deaths_per_million                      float64
# new_deaths_per_million                        float64
# new_deaths_smoothed_per_million               float64
# excess_mortality                              float64
# excess_mortality_cumulative                   float64
# excess_mortality_cumulative_absolute          float64
# ...

# %%
data_types = pd.DataFrame({
    "Column": df.columns,
    "Data_Type": df.dtypes.astype(str).values
})

data_types
# Out:
#                                         Column Data_Type
# 0                                      country    object
# 1                                         date    object
# 2                                  total_cases   float64
# 3                                    new_cases   float64
# 4                           new_cases_smoothed   float64
# 5                      total_cases_per_million   float64
# 6                        new_cases_per_million   float64
# 7               new_cases_smoothed_per_million   float64
# 8                                 total_deaths   float64
# 9                                   new_deaths   float64
# 10                         new_deaths_smoothed   float64
# 11                    total_deaths_per_million   float64
# 12                      new_deaths_per_million   float64
# 13             new_deaths_smoothed_per_million   float64
# 14                            excess_mortality   float64
# ...

# %%
df["date"] = pd.to_datetime(df["date"])

# %%
print(df["date"].dtype)
# Out:
# datetime64[ns]

# %%
print("Earliest date:", df["date"].min())
print("Latest date:", df["date"].max())
# Out:
# Earliest date: 2020-01-01 00:00:00
# Latest date: 2026-08-30 00:00:00

# %%
number_of_countries = df["country"].nunique()

print("Unique countries/locations:", number_of_countries)
# Out:
# Unique countries/locations: 262

# %%
countries = df["country"].unique()

print(countries)
# Out:
# ['Afghanistan' 'Africa' 'Albania' 'Algeria' 'American Samoa' 'Andorra'
#  'Angola' 'Anguilla' 'Antigua and Barbuda' 'Argentina' 'Armenia' 'Aruba'
#  'Asia' 'Asia excl. China' 'Australia' 'Austria' 'Azerbaijan' 'Bahamas'
#  'Bahrain' 'Bangladesh' 'Barbados' 'Belarus' 'Belgium' 'Belize' 'Benin'
#  'Bermuda' 'Bhutan' 'Bolivia' 'Bonaire Sint Eustatius and Saba'
#  'Bosnia and Herzegovina' 'Botswana' 'Brazil' 'British Virgin Islands'
#  'Brunei' 'Bulgaria' 'Burkina Faso' 'Burundi' 'Cambodia' 'Cameroon'
#  'Canada' 'Cape Verde' 'Cayman Islands' 'Central African Republic' 'Chad'
#  'Chile' 'China' 'Colombia' 'Comoros' 'Congo' 'Cook Islands' 'Costa Rica'
#  "Cote d'Ivoire" 'Croatia' 'Cuba' 'Curacao' 'Cyprus' 'Czechia'
#  'Democratic Republic of Congo' 'Denmark' 'Djibouti' 'Dominica'
#  'Dominican Republic' 'East Timor' 'Ecuador' 'Egypt' 'El Salvador'
#  'England' 'England and Wales' 'Equatorial Guinea' 'Eritrea' 'Estonia'
# ...

# %%
country_counts = (
    df["country"]
    .value_counts()
)

country_counts.head(20)
# Out:
# country
# Zimbabwe                        2434
# Afghanistan                     2434
# Albania                         2434
# Algeria                         2434
# Uruguay                         2434
# United States Virgin Islands    2434
# United Arab Emirates            2434
# United Kingdom                  2434
# United States                   2434
# Cambodia                        2434
# Burundi                         2434
# Trinidad and Tobago             2434
# Ukraine                         2434
# Uganda                          2434
# Turkmenistan                    2434
# Tunisia                         2434
# Turkey                          2434
# Burkina Faso                    2434
# Bulgaria                        2434
# Tonga                           2434
# Name: count, dtype: int64

# %%
duplicate_count = df.duplicated().sum()

print("Duplicate rows:", duplicate_count)
# Out:
# Duplicate rows: 0

# %%
missing_count = df.isnull().sum()

missing_count
# Out:
# country                                            0
# date                                               0
# total_cases                                    12348
# new_cases                                      17044
# new_cases_smoothed                             18253
# total_cases_per_million                        12348
# new_cases_per_million                          17044
# new_cases_smoothed_per_million                 18253
# total_deaths                                   12348
# new_deaths                                     15830
# new_deaths_smoothed                            17042
# total_deaths_per_million                       12348
# new_deaths_per_million                         15830
# new_deaths_smoothed_per_million                17042
# excess_mortality                              603789
# excess_mortality_cumulative                   603789
# excess_mortality_cumulative_absolute          603789
# excess_mortality_cumulative_per_million       603823
# ...

# %%
missing_summary = pd.DataFrame({
    "Column": df.columns,
    "Missing_Count": df.isnull().sum().values,
    "Missing_Percentage": (
        df.isnull().mean().values * 100
    )
})

missing_summary = missing_summary.sort_values(
    by="Missing_Percentage",
    ascending=False
)

missing_summary
# Out:
#                                         Column  Missing_Count  \
# 60                     human_development_index         617667
# 24                       weekly_icu_admissions         606674
# 25           weekly_icu_admissions_per_million         606674
# 17     excess_mortality_cumulative_per_million         603823
# 14                            excess_mortality         603789
# 15                 excess_mortality_cumulative         603789
# 16        excess_mortality_cumulative_absolute         603789
# 21          weekly_hosp_admissions_per_million         593170
# 20                      weekly_hosp_admissions         593170
# 22                                icu_patients         578551
# 23                    icu_patients_per_million         578551
# 19                   hosp_patients_per_million         577011
# 18                               hosp_patients         577011
# 39                              total_boosters         558883
# ...

# %%
plt.figure(figsize=(14, 8))

top_missing = missing_summary.head(20)

sns.barplot(
    data=top_missing,
    x="Missing_Percentage",
    y="Column"
)

plt.title("Top 20 Variables by Missing Values")
plt.xlabel("Missing Values (%)")
plt.ylabel("Variable")

plt.tight_layout()
plt.show()

# %%
df.describe()
# Out:
#                                 date   total_cases     new_cases  \
# count                         617667  6.053190e+05  6.006230e+05
# mean   2023-04-22 11:33:58.855888128  1.525363e+07  9.056902e+03
# min              2020-01-01 00:00:00  0.000000e+00  0.000000e+00
# 25%              2021-08-25 00:00:00  1.105100e+04  0.000000e+00
# 50%              2023-04-14 00:00:00  9.804100e+04  0.000000e+00
# 75%              2024-12-18 00:00:00  1.197082e+06  2.500000e+01
# max              2026-08-30 00:00:00  7.792774e+08  8.401906e+06
# std                              NaN  7.742800e+07  1.088269e+05
#
#        new_cases_smoothed  total_cases_per_million  new_cases_per_million  \
# count        5.994140e+05            605319.000000          600623.000000
# mean         9.075189e+03            140898.725384              84.903229
# min          0.000000e+00                 0.000000               0.000000
# 25%          0.000000e+00              4016.732400               0.000000
# ...

# %%
df.describe().T
# Out:
#                                                count  \
# date                                          617667
# total_cases                                 605319.0
# new_cases                                   600623.0
# new_cases_smoothed                          599414.0
# total_cases_per_million                     605319.0
# new_cases_per_million                       600623.0
# new_cases_smoothed_per_million              599414.0
# total_deaths                                605319.0
# new_deaths                                  601837.0
# new_deaths_smoothed                         600625.0
# total_deaths_per_million                    605319.0
# new_deaths_per_million                      601837.0
# new_deaths_smoothed_per_million             600625.0
# excess_mortality                             13878.0
# excess_mortality_cumulative                  13878.0
# excess_mortality_cumulative_absolute         13878.0
# excess_mortality_cumulative_per_million      13844.0
# ...

# %%
df["country"].describe()
# Out:
# count       617667
# unique         262
# top       Zimbabwe
# freq          2434
# Name: country, dtype: object

# %%
df["continent"].describe()
# Out:
# count     572427
# unique         6
# top       Africa
# freq      137430
# Name: continent, dtype: object

# %%
print("Total observations:", len(df))
print("Number of countries:", df["country"].nunique())
print("Number of continents:", df["continent"].nunique())
print("Start date:", df["date"].min())
print("End date:", df["date"].max())
# Out:
# Total observations: 617667
# Number of countries: 262
# Number of continents: 6
# Start date: 2020-01-01 00:00:00
# End date: 2026-08-30 00:00:00

# %%
dataset_summary = pd.DataFrame({
    "Metric": [
        "Number of Rows",
        "Number of Columns",
        "Unique Countries",
        "Unique Continents",
        "Start Date",
        "End Date",
        "Duplicate Rows"
    ],

    "Value": [
        df.shape[0],
        df.shape[1],
        df["country"].nunique(),
        df["continent"].nunique(),
        df["date"].min(),
        df["date"].max(),
        df.duplicated().sum()
    ]
})

dataset_summary
# Out:
#               Metric                Value
# 0     Number of Rows               617667
# 1  Number of Columns                   61
# 2   Unique Countries                  262
# 3  Unique Continents                    6
# 4         Start Date  2020-01-01 00:00:00
# 5           End Date  2026-08-30 00:00:00
# 6     Duplicate Rows                    0

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 617667 entries, 0 to 617666
# Data columns (total 61 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   country                                     617667 non-null  object
#  1   date                                        617667 non-null  datetime64[ns]
#  2   total_cases                                 605319 non-null  float64
#  3   new_cases                                   600623 non-null  float64
#  4   new_cases_smoothed                          599414 non-null  float64
#  5   total_cases_per_million                     605319 non-null  float64
#  6   new_cases_per_million                       600623 non-null  float64
#  7   new_cases_smoothed_per_million              599414 non-null  float64
#  8   total_deaths                                605319 non-null  float64
# ...

# %%
print(df["date"].min())
print(df["date"].max())
# Out:
# 2020-01-01 00:00:00
# 2026-08-30 00:00:00

# %%
print(df["country"].nunique())
# Out:
# 262

# %%
missing_summary.head(20)
# Out:
#                                      Column  Missing_Count  Missing_Percentage
# 60                  human_development_index         617667          100.000000
# 24                    weekly_icu_admissions         606674           98.220238
# 25        weekly_icu_admissions_per_million         606674           98.220238
# 17  excess_mortality_cumulative_per_million         603823           97.758663
# 14                         excess_mortality         603789           97.753158
# 15              excess_mortality_cumulative         603789           97.753158
# 16     excess_mortality_cumulative_absolute         603789           97.753158
# 21       weekly_hosp_admissions_per_million         593170           96.033947
# 20                   weekly_hosp_admissions         593170           96.033947
# 22                             icu_patients         578551           93.667138
# 23                 icu_patients_per_million         578551           93.667138
# ...

# %%
df_clean = df.copy()

print("Clean working dataset created.")
print("Rows:", df_clean.shape[0])
print("Columns:", df_clean.shape[1])
# Out:
# Clean working dataset created.
# Rows: 617667
# Columns: 61

# %%
country_date_duplicates = df_clean.duplicated(
    subset=["country", "date"]
).sum()

print("Duplicate country-date combinations:", country_date_duplicates)
# Out:
# Duplicate country-date combinations: 0

# %%
print("Date data type:", df_clean["date"].dtype)
print("Minimum date:", df_clean["date"].min())
print("Maximum date:", df_clean["date"].max())
# Out:
# Date data type: datetime64[ns]
# Minimum date: 2020-01-01 00:00:00
# Maximum date: 2026-08-30 00:00:00

# %%
missing_dates = df_clean["date"].isna().sum()

print("Missing dates:", missing_dates)
# Out:
# Missing dates: 0

# %%
non_negative_columns = [
    "total_cases",
    "new_cases",
    "total_deaths",
    "new_deaths",
    "total_tests",
    "new_tests",
    "total_vaccinations",
    "people_vaccinated",
    "people_fully_vaccinated",
    "total_boosters",
    "new_vaccinations"
]

# %%
negative_values = {}

for column in non_negative_columns:
    negative_count = (df_clean[column] < 0).sum()
    negative_values[column] = negative_count

negative_values
# Out:
# {'total_cases': np.int64(0),
#  'new_cases': np.int64(0),
#  'total_deaths': np.int64(0),
#  'new_deaths': np.int64(0),
#  'total_tests': np.int64(0),
#  'new_tests': np.int64(0),
#  'total_vaccinations': np.int64(0),
#  'people_vaccinated': np.int64(0),
#  'people_fully_vaccinated': np.int64(0),
#  'total_boosters': np.int64(0),
#  'new_vaccinations': np.int64(0)}

# %%
negative_summary = pd.DataFrame(
    list(negative_values.items()),
    columns=["Column", "Negative_Values"]
)

negative_summary
# Out:
#                      Column  Negative_Values
# 0               total_cases                0
# 1                 new_cases                0
# 2              total_deaths                0
# 3                new_deaths                0
# 4               total_tests                0
# 5                 new_tests                0
# 6        total_vaccinations                0
# 7         people_vaccinated                0
# 8   people_fully_vaccinated                0
# 9            total_boosters                0
# 10         new_vaccinations                0

# %%
percentage_columns = [
    "total_vaccinations_per_hundred",
    "people_vaccinated_per_hundred",
    "people_fully_vaccinated_per_hundred",
    "total_boosters_per_hundred"
]

percentage_check = {}

for column in percentage_columns:
    percentage_check[column] = {
        "Above_100": (df_clean[column] > 100).sum(),
        "Below_0": (df_clean[column] < 0).sum()
    }

percentage_check
# Out:
# {'total_vaccinations_per_hundred': {'Above_100': np.int64(48175),
#   'Below_0': np.int64(0)},
#  'people_vaccinated_per_hundred': {'Above_100': np.int64(174),
#   'Below_0': np.int64(0)},
#  'people_fully_vaccinated_per_hundred': {'Above_100': np.int64(159),
#   'Below_0': np.int64(0)},
#  'total_boosters_per_hundred': {'Above_100': np.int64(825),
#   'Below_0': np.int64(0)}}

# %%
print(
    "People vaccinated > 100:",
    (df_clean["people_vaccinated_per_hundred"] > 100).sum()
)

print(
    "People vaccinated < 0:",
    (df_clean["people_vaccinated_per_hundred"] < 0).sum()
)
# Out:
# People vaccinated > 100: 174
# People vaccinated < 0: 0

# %%
print(
    "People fully vaccinated > 100:",
    (df_clean["people_fully_vaccinated_per_hundred"] > 100).sum()
)

print(
    "People fully vaccinated < 0:",
    (df_clean["people_fully_vaccinated_per_hundred"] < 0).sum()
)
# Out:
# People fully vaccinated > 100: 159
# People fully vaccinated < 0: 0

# %%
print(
    "Positive rate below 0:",
    (df_clean["positive_rate"] < 0).sum()
)

print(
    "Positive rate above 1:",
    (df_clean["positive_rate"] > 1).sum()
)
# Out:
# Positive rate below 0: 0
# Positive rate above 1: 82451

# %%
print(
    "Negative reproduction rates:",
    (df_clean["reproduction_rate"] < 0).sum()
)
# Out:
# Negative reproduction rates: 1781

# %%
print("Missing population:", df_clean["population"].isna().sum())
print("Zero population:", (df_clean["population"] == 0).sum())
print("Negative population:", (df_clean["population"] < 0).sum())
# Out:
# Missing population: 18547
# Zero population: 0
# Negative population: 0

# %%
country_record_counts = (
    df_clean.groupby("country")
    .size()
    .sort_values(ascending=False)
)

country_record_counts.head(20)
# Out:
# country
# Zimbabwe                        2434
# Afghanistan                     2434
# Albania                         2434
# Algeria                         2434
# Uruguay                         2434
# United States Virgin Islands    2434
# United Arab Emirates            2434
# United Kingdom                  2434
# United States                   2434
# Cambodia                        2434
# Burundi                         2434
# Trinidad and Tobago             2434
# Ukraine                         2434
# Uganda                          2434
# Turkmenistan                    2434
# Tunisia                         2434
# Turkey                          2434
# Burkina Faso                    2434
# Bulgaria                        2434
# Tonga                           2434
# dtype: int64

# %%
country_record_counts.tail(20)
# Out:
# country
# World excl. China       2431
# World                   2431
# Asia excl. China        2431
# Armenia                 2431
# Asia                    2431
# Antigua and Barbuda     2431
# Anguilla                2431
# Hong Kong               1672
# Taiwan                  1386
# Northern Ireland        1385
# England                 1359
# Scotland                1327
# Macao                   1208
# Wales                   1198
# Cote d'Ivoire           1146
# Summer Olympics 2020     525
# Winter Olympics 2022     341
# England and Wales        209
# Transnistria              48
# Western Sahara             1
# dtype: int64

# %%
missing_code = df_clean[df_clean["code"].isna()]

print("Rows with missing country code:", len(missing_code))
# Out:
# Rows with missing country code: 25792

# %%
missing_code["country"].drop_duplicates().tolist()
# Out:
# ['Asia excl. China',
#  'England',
#  'England and Wales',
#  'High-income countries',
#  'Low-income countries',
#  'Lower-middle-income countries',
#  'Northern Ireland',
#  'Scotland',
#  'Summer Olympics 2020',
#  'Upper-middle-income countries',
#  'Wales',
#  'Winter Olympics 2022',
#  'World excl. China',
#  'World excl. China and South Korea',
#  'World excl. China, South Korea, Japan and Singapore']

# %%
missing_code[["country", "continent"]].drop_duplicates().head(100)
# Out:
#                                                   country continent
# 31624                                    Asia excl. China       NaN
# 159317                                            England       NaN
# 160676                                  England and Wales       NaN
# 236306                              High-income countries       NaN
# 310989                               Low-income countries       NaN
# 313420                      Lower-middle-income countries       NaN
# 402210                                   Northern Ireland       NaN
# 481441                                           Scotland       NaN
# 524140                               Summer Olympics 2020       NaN
# 579638                      Upper-middle-income countries       NaN
# 596670                                              Wales       NaN
# 600300                               Winter Olympics 2022       NaN
# 603072                                  World excl. China       NaN
# ...

# %%
missing_summary = pd.DataFrame({
    "Column": df_clean.columns,
    "Missing_Count": df_clean.isna().sum().values,
    "Missing_Percentage": (
        df_clean.isna().mean().values * 100
    )
})

missing_summary = missing_summary.sort_values(
    by="Missing_Percentage",
    ascending=False
)

missing_summary
# Out:
#                                         Column  Missing_Count  \
# 60                     human_development_index         617667
# 24                       weekly_icu_admissions         606674
# 25           weekly_icu_admissions_per_million         606674
# 17     excess_mortality_cumulative_per_million         603823
# 14                            excess_mortality         603789
# 15                 excess_mortality_cumulative         603789
# 16        excess_mortality_cumulative_absolute         603789
# 21          weekly_hosp_admissions_per_million         593170
# 20                      weekly_hosp_admissions         593170
# 22                                icu_patients         578551
# 23                    icu_patients_per_million         578551
# 19                   hosp_patients_per_million         577011
# 18                               hosp_patients         577011
# 39                              total_boosters         558883
# ...

# %%
missing_summary[
    missing_summary["Missing_Count"] > 0
]
# Out:
#                                         Column  Missing_Count  \
# 60                     human_development_index         617667
# 24                       weekly_icu_admissions         606674
# 25           weekly_icu_admissions_per_million         606674
# 17     excess_mortality_cumulative_per_million         603823
# 14                            excess_mortality         603789
# 15                 excess_mortality_cumulative         603789
# 16        excess_mortality_cumulative_absolute         603789
# 21          weekly_hosp_admissions_per_million         593170
# 20                      weekly_hosp_admissions         593170
# 22                                icu_patients         578551
# 23                    icu_patients_per_million         578551
# 19                   hosp_patients_per_million         577011
# 18                               hosp_patients         577011
# 39                              total_boosters         558883
# ...

# %%
low_missing = missing_summary[
    (missing_summary["Missing_Percentage"] > 0) &
    (missing_summary["Missing_Percentage"] <= 5)
]

low_missing
# Out:
#                              Column  Missing_Count  Missing_Percentage
# 52               population_density          28274            4.577547
# 53                       median_age          25840            4.183484
# 49                             code          25792            4.175713
# 54                  life_expectancy          23409            3.789906
# 51                       population          18547            3.002751
# 7    new_cases_smoothed_per_million          18253            2.955152
# 4                new_cases_smoothed          18253            2.955152
# 6             new_cases_per_million          17044            2.759416
# 3                         new_cases          17044            2.759416
# 13  new_deaths_smoothed_per_million          17042            2.759092
# 10              new_deaths_smoothed          17042            2.759092
# 12           new_deaths_per_million          15830            2.562870
# ...

# %%
medium_missing = missing_summary[
    (missing_summary["Missing_Percentage"] > 5) &
    (missing_summary["Missing_Percentage"] <= 30)
]

medium_missing
# Out:
#                  Column  Missing_Count  Missing_Percentage
# 55       gdp_per_capita         122060           19.761457
# 57  diabetes_prevalence          97726           15.821794
# 50            continent          45240            7.324335

# %%
high_missing = missing_summary[
    missing_summary["Missing_Percentage"] > 30
]

high_missing
# Out:
#                                         Column  Missing_Count  \
# 60                     human_development_index         617667
# 24                       weekly_icu_admissions         606674
# 25           weekly_icu_admissions_per_million         606674
# 17     excess_mortality_cumulative_per_million         603823
# 14                            excess_mortality         603789
# 15                 excess_mortality_cumulative         603789
# 16        excess_mortality_cumulative_absolute         603789
# 21          weekly_hosp_admissions_per_million         593170
# 20                      weekly_hosp_admissions         593170
# 22                                icu_patients         578551
# 23                    icu_patients_per_million         578551
# 19                   hosp_patients_per_million         577011
# 18                               hosp_patients         577011
# 39                              total_boosters         558883
# ...

# %%
print("========== DATA QUALITY REPORT ==========")

print("Rows:", df_clean.shape[0])
print("Columns:", df_clean.shape[1])

print("\nDuplicate rows:")
print(df_clean.duplicated().sum())

print("\nDuplicate country-date combinations:")
print(df_clean.duplicated(
    subset=["country", "date"]
).sum())

print("\nMissing dates:")
print(df_clean["date"].isna().sum())

print("\nNegative total cases:")
print((df_clean["total_cases"] < 0).sum())

print("\nNegative total deaths:")
print((df_clean["total_deaths"] < 0).sum())

print("\nNegative population:")
print((df_clean["population"] < 0).sum())

print("\n==========================================")
# Out:
# ========== DATA QUALITY REPORT ==========
# Rows: 617667
# Columns: 61
#
# Duplicate rows:
# 0
#
# Duplicate country-date combinations:
# 0
#
# Missing dates:
# 0
#
# Negative total cases:
# 0
#
# Negative total deaths:
# 0
#
# Negative population:
# 0
#
# ...

# %%
df_clean.duplicated(
    subset=["country", "date"]
).sum()
# Out:
# np.int64(0)

# %%
negative_summary
# Out:
#                      Column  Negative_Values
# 0               total_cases                0
# 1                 new_cases                0
# 2              total_deaths                0
# 3                new_deaths                0
# 4               total_tests                0
# 5                 new_tests                0
# 6        total_vaccinations                0
# 7         people_vaccinated                0
# 8   people_fully_vaccinated                0
# 9            total_boosters                0
# 10         new_vaccinations                0

# %%
percentage_check
# Out:
# {'total_vaccinations_per_hundred': {'Above_100': np.int64(48175),
#   'Below_0': np.int64(0)},
#  'people_vaccinated_per_hundred': {'Above_100': np.int64(174),
#   'Below_0': np.int64(0)},
#  'people_fully_vaccinated_per_hundred': {'Above_100': np.int64(159),
#   'Below_0': np.int64(0)},
#  'total_boosters_per_hundred': {'Above_100': np.int64(825),
#   'Below_0': np.int64(0)}}

# %%
missing_code["country"].drop_duplicates().tolist()
# Out:
# ['Asia excl. China',
#  'England',
#  'England and Wales',
#  'High-income countries',
#  'Low-income countries',
#  'Lower-middle-income countries',
#  'Northern Ireland',
#  'Scotland',
#  'Summer Olympics 2020',
#  'Upper-middle-income countries',
#  'Wales',
#  'Winter Olympics 2022',
#  'World excl. China',
#  'World excl. China and South Korea',
#  'World excl. China, South Korea, Japan and Singapore']

# %%
missing_summary
# Out:
#                                         Column  Missing_Count  \
# 60                     human_development_index         617667
# 24                       weekly_icu_admissions         606674
# 25           weekly_icu_admissions_per_million         606674
# 17     excess_mortality_cumulative_per_million         603823
# 14                            excess_mortality         603789
# 15                 excess_mortality_cumulative         603789
# 16        excess_mortality_cumulative_absolute         603789
# 21          weekly_hosp_admissions_per_million         593170
# 20                      weekly_hosp_admissions         593170
# 22                                icu_patients         578551
# 23                    icu_patients_per_million         578551
# 19                   hosp_patients_per_million         577011
# 18                               hosp_patients         577011
# 39                              total_boosters         558883
# ...

# %%
vaccination_over_100 = df_clean[
    (df_clean["people_vaccinated_per_hundred"] > 100) |
    (df_clean["people_fully_vaccinated_per_hundred"] > 100)
]

vaccination_over_100[
    [
        "country",
        "date",
        "population",
        "people_vaccinated",
        "people_fully_vaccinated",
        "people_vaccinated_per_hundred",
        "people_fully_vaccinated_per_hundred"
    ]
].head(50)
# Out:
#              country       date  population  people_vaccinated  \
# 120026  Cook Islands 2022-03-07     14747.0            14930.0
# 120033  Cook Islands 2022-03-14     14747.0            14992.0
# 120040  Cook Islands 2022-03-21     14747.0            14992.0
# 120047  Cook Islands 2022-03-28     14747.0            14992.0
# 120054  Cook Islands 2022-04-04     14747.0            15004.0
# 120117  Cook Islands 2022-06-06     14747.0            15033.0
# 120264  Cook Islands 2022-10-31     14747.0            15084.0
# 120271  Cook Islands 2022-11-07     14747.0            15084.0
# 120299  Cook Islands 2022-12-05     14747.0            15084.0
# 120369  Cook Islands 2023-02-13     14747.0            15112.0
# 207600     Gibraltar 2021-05-05     37631.0            37988.0
# 207601     Gibraltar 2021-05-06     37631.0            38454.0
# 207602     Gibraltar 2021-05-07     37631.0            38727.0
# 207608     Gibraltar 2021-05-13     37631.0            38905.0
# ...

# %%
df_clean = df_clean.drop(columns=["human_development_index"])

print("human_development_index removed.")
print("New shape:", df_clean.shape)
# Out:
# human_development_index removed.
# New shape: (617667, 60)

# %%
missing_code_countries = (
    df_clean.loc[df_clean["code"].isna(), "country"]
    .drop_duplicates()
    .sort_values()
)

print("Number of entities without code:", len(missing_code_countries))
print(missing_code_countries.tolist())
# Out:
# Number of entities without code: 15
# ['Asia excl. China', 'England', 'England and Wales', 'High-income countries', 'Low-income countries', 'Lower-middle-income countries', 'Northern Ireland', 'Scotland', 'Summer Olympics 2020', 'Upper-middle-income countries', 'Wales', 'Winter Olympics 2022', 'World excl. China', 'World excl. China and South Korea', 'World excl. China, South Korea, Japan and Singapore']

# %%
df_countries = df_clean[
    df_clean["code"].notna()
].copy()

print("Country-level rows:", len(df_countries))
print("Countries/entities:", df_countries["country"].nunique())
# Out:
# Country-level rows: 591875
# Countries/entities: 247

# %%
df_countries = df_clean[
    df_clean["code"].notna()
].copy()

print("Country-level rows:", len(df_countries))
print("Countries/entities:", df_countries["country"].nunique())
# Out:
# Country-level rows: 591875
# Countries/entities: 247

# %%
df_aggregates = df_clean[
    df_clean["code"].isna()
].copy()

print("Aggregate/non-coded rows:", len(df_aggregates))
print(
    "Aggregate entities:",
    df_aggregates["country"].nunique()
)
# Out:
# Aggregate/non-coded rows: 25792
# Aggregate entities: 15

# %%
df_aggregates["country"].drop_duplicates().sort_values().tolist()
# Out:
# ['Asia excl. China',
#  'England',
#  'England and Wales',
#  'High-income countries',
#  'Low-income countries',
#  'Lower-middle-income countries',
#  'Northern Ireland',
#  'Scotland',
#  'Summer Olympics 2020',
#  'Upper-middle-income countries',
#  'Wales',
#  'Winter Olympics 2022',
#  'World excl. China',
#  'World excl. China and South Korea',
#  'World excl. China, South Korea, Japan and Singapore']

# %%
population_missing = df_countries["population"].isna().sum()

print("Country rows with missing population:", population_missing)
print(
    "Percentage:",
    round(
        df_countries["population"].isna().mean() * 100,
        2
    ),
    "%"
)
# Out:
# Country rows with missing population: 2479
# Percentage: 0.42 %

# %%
df_countries[
    df_countries["population"].isna()
][
    ["country", "date", "code"]
].drop_duplicates().head(50)
# Out:
#          country       date code
# 432794  Pitcairn 2020-01-04  PCN
# 432795  Pitcairn 2020-01-05  PCN
# 432796  Pitcairn 2020-01-06  PCN
# 432797  Pitcairn 2020-01-07  PCN
# 432798  Pitcairn 2020-01-08  PCN
# 432799  Pitcairn 2020-01-09  PCN
# 432800  Pitcairn 2020-01-10  PCN
# 432801  Pitcairn 2020-01-11  PCN
# 432802  Pitcairn 2020-01-12  PCN
# 432803  Pitcairn 2020-01-13  PCN
# 432804  Pitcairn 2020-01-14  PCN
# 432805  Pitcairn 2020-01-15  PCN
# 432806  Pitcairn 2020-01-16  PCN
# 432807  Pitcairn 2020-01-17  PCN
# 432808  Pitcairn 2020-01-18  PCN
# 432809  Pitcairn 2020-01-19  PCN
# 432810  Pitcairn 2020-01-20  PCN
# 432811  Pitcairn 2020-01-21  PCN
# 432812  Pitcairn 2020-01-22  PCN
# 432813  Pitcairn 2020-01-23  PCN
# 432814  Pitcairn 2020-01-24  PCN
# 432815  Pitcairn 2020-01-25  PCN
# 432816  Pitcairn 2020-01-26  PCN
# 432817  Pitcairn 2020-01-27  PCN
# 432818  Pitcairn 2020-01-28  PCN
# 432819  Pitcairn 2020-01-29  PCN
# 432820  Pitcairn 2020-01-30  PCN
# ...

# %%
country_missing_summary = pd.DataFrame({
    "Column": df_countries.columns,
    "Missing_Count": df_countries.isna().sum().values,
    "Missing_Percentage": (
        df_countries.isna().mean().values * 100
    )
})

country_missing_summary = country_missing_summary.sort_values(
    by="Missing_Percentage",
    ascending=False
)

country_missing_summary
# Out:
#                                         Column  Missing_Count  \
# 25           weekly_icu_admissions_per_million         580882
# 24                       weekly_icu_admissions         580882
# 17     excess_mortality_cumulative_per_million         578031
# 15                 excess_mortality_cumulative         577997
# 14                            excess_mortality         577997
# 16        excess_mortality_cumulative_absolute         577997
# 20                      weekly_hosp_admissions         572209
# 21          weekly_hosp_admissions_per_million         572209
# 22                                icu_patients         557050
# 23                    icu_patients_per_million         557050
# 18                               hosp_patients         556433
# 19                   hosp_patients_per_million         556433
# 45                  total_boosters_per_hundred         538491
# 39                              total_boosters         538491
# ...

# %%
core_columns = [
    "total_cases",
    "new_cases",
    "total_deaths",
    "new_deaths",
    "total_cases_per_million",
    "new_cases_per_million",
    "total_deaths_per_million",
    "new_deaths_per_million",
    "population"
]

core_missing = pd.DataFrame({
    "Column": core_columns,
    "Missing_Count": [
        df_countries[col].isna().sum()
        for col in core_columns
    ],
    "Missing_Percentage": [
        df_countries[col].isna().mean() * 100
        for col in core_columns
    ]
})

core_missing
# Out:
#                      Column  Missing_Count  Missing_Percentage
# 0               total_cases           6004            1.014403
# 1                 new_cases          10700            1.807814
# 2              total_deaths           6004            1.014403
# 3                new_deaths           9486            1.602703
# 4   total_cases_per_million           6004            1.014403
# 5     new_cases_per_million          10700            1.807814
# 6  total_deaths_per_million           6004            1.014403
# 7    new_deaths_per_million           9486            1.602703
# 8                population           2479            0.418838

# %%
df_check = df_countries.sort_values(
    ["country", "date"]
).copy()

df_check["cases_change"] = (
    df_check.groupby("country")["total_cases"]
    .diff()
)

decreasing_cases = df_check[
    df_check["cases_change"] < 0
]

print("Rows where total_cases decreased:",
      len(decreasing_cases))
# Out:
# Rows where total_cases decreased: 58

# %%
df_check["deaths_change"] = (
    df_check.groupby("country")["total_deaths"]
    .diff()
)

decreasing_deaths = df_check[
    df_check["deaths_change"] < 0
]

print("Rows where total_deaths decreased:",
      len(decreasing_deaths))
# Out:
# Rows where total_deaths decreased: 37

# %%
df_check["vaccination_change"] = (
    df_check.groupby("country")["total_vaccinations"]
    .diff()
)

decreasing_vaccinations = df_check[
    df_check["vaccination_change"] < 0
]

print(
    "Rows where total_vaccinations decreased:",
    len(decreasing_vaccinations)
)
# Out:
# Rows where total_vaccinations decreased: 0

# %%
df_clean.to_csv(
    "covid19_cleaned.csv",
    index=False
)

df_countries.to_csv(
    "covid19_country_data.csv",
    index=False
)

df_aggregates.to_csv(
    "covid19_aggregate_data.csv",
    index=False
)

print("Cleaned datasets saved successfully.")
# Out:
# Cleaned datasets saved successfully.

# %%
vaccination_over_100[
    [
        "country",
        "date",
        "population",
        "people_vaccinated",
        "people_fully_vaccinated",
        "people_vaccinated_per_hundred",
        "people_fully_vaccinated_per_hundred"
    ]
].head(50)
# Out:
#              country       date  population  people_vaccinated  \
# 120026  Cook Islands 2022-03-07     14747.0            14930.0
# 120033  Cook Islands 2022-03-14     14747.0            14992.0
# 120040  Cook Islands 2022-03-21     14747.0            14992.0
# 120047  Cook Islands 2022-03-28     14747.0            14992.0
# 120054  Cook Islands 2022-04-04     14747.0            15004.0
# 120117  Cook Islands 2022-06-06     14747.0            15033.0
# 120264  Cook Islands 2022-10-31     14747.0            15084.0
# 120271  Cook Islands 2022-11-07     14747.0            15084.0
# 120299  Cook Islands 2022-12-05     14747.0            15084.0
# 120369  Cook Islands 2023-02-13     14747.0            15112.0
# 207600     Gibraltar 2021-05-05     37631.0            37988.0
# 207601     Gibraltar 2021-05-06     37631.0            38454.0
# 207602     Gibraltar 2021-05-07     37631.0            38727.0
# 207608     Gibraltar 2021-05-13     37631.0            38905.0
# ...

# %%
print(len(df_countries))
print(df_countries["country"].nunique())
# Out:
# 591875
# 247

# %%
print("Cases decreased:", len(decreasing_cases))
print("Deaths decreased:", len(decreasing_deaths))
print("Vaccinations decreased:", len(decreasing_vaccinations))
# Out:
# Cases decreased: 58
# Deaths decreased: 37
# Vaccinations decreased: 0

# %%
core_missing
# Out:
#                      Column  Missing_Count  Missing_Percentage
# 0               total_cases           6004            1.014403
# 1                 new_cases          10700            1.807814
# 2              total_deaths           6004            1.014403
# 3                new_deaths           9486            1.602703
# 4   total_cases_per_million           6004            1.014403
# 5     new_cases_per_million          10700            1.807814
# 6  total_deaths_per_million           6004            1.014403
# 7    new_deaths_per_million           9486            1.602703
# 8                population           2479            0.418838

# %%
global_daily = (
    df_countries
    .groupby("date", as_index=False)
    .agg({
        "new_cases": "sum",
        "new_deaths": "sum",
        "new_tests": "sum",
        "new_vaccinations": "sum"
    })
)

global_daily.head()
# Out:
#         date  new_cases  new_deaths  new_tests  new_vaccinations
# 0 2020-01-01        0.0         0.0       29.0               0.0
# 1 2020-01-02        0.0         0.0      167.0               0.0
# 2 2020-01-03        0.0         0.0       94.0               0.0
# 3 2020-01-04       11.0         0.0      123.0               0.0
# 4 2020-01-05        0.0        12.0       97.0               0.0

# %%
plt.figure(figsize=(15, 6))

plt.plot(
    global_daily["date"],
    global_daily["new_cases"]
)

plt.title("Global Daily New COVID-19 Cases")
plt.xlabel("Date")
plt.ylabel("New Cases")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 6))

plt.plot(
    global_daily["date"],
    global_daily["new_deaths"]
)

plt.title("Global Daily New COVID-19 Deaths")
plt.xlabel("Date")
plt.ylabel("New Deaths")

plt.tight_layout()
plt.show()

# %%
global_daily["cases_7day_avg"] = (
    global_daily["new_cases"]
    .rolling(window=7)
    .mean()
)

global_daily["deaths_7day_avg"] = (
    global_daily["new_deaths"]
    .rolling(window=7)
    .mean()
)

# %%
plt.figure(figsize=(15, 6))

plt.plot(
    global_daily["date"],
    global_daily["cases_7day_avg"]
)

plt.title("Global COVID-19 Cases — 7-Day Moving Average")
plt.xlabel("Date")
plt.ylabel("Average Daily New Cases")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 6))

plt.plot(
    global_daily["date"],
    global_daily["deaths_7day_avg"]
)

plt.title("Global COVID-19 Deaths — 7-Day Moving Average")
plt.xlabel("Date")
plt.ylabel("Average Daily New Deaths")

plt.tight_layout()
plt.show()

# %%
peak_cases_row = global_daily.loc[
    global_daily["new_cases"].idxmax()
]

peak_cases_row
# Out:
# date                2022-01-30 00:00:00
# new_cases                    31101814.0
# new_deaths                      60086.0
# new_tests                     9315531.0
# new_vaccinations           53398194.715
# cases_7day_avg               11305587.0
# deaths_7day_avg            30947.571429
# Name: 760, dtype: object

# %%
print("Peak reported global daily cases:")
print("Date:", peak_cases_row["date"])
print("Cases:", peak_cases_row["new_cases"])
# Out:
# Peak reported global daily cases:
# Date: 2022-01-30 00:00:00
# Cases: 31101814.0

# %%
peak_deaths_row = global_daily.loc[
    global_daily["new_deaths"].idxmax()
]

print("Peak reported global daily deaths:")
print("Date:", peak_deaths_row["date"])
print("Deaths:", peak_deaths_row["new_deaths"])
# Out:
# Peak reported global daily deaths:
# Date: 2023-02-01 00:00:00
# Deaths: 171685.0

# %%
latest_country_data = (
    df_countries
    .sort_values("date")
    .groupby("country")
    .tail(1)
    .copy()
)

latest_country_data[
    [
        "country",
        "date",
        "total_cases",
        "total_deaths",
        "population"
    ]
].head()
# Out:
#                country       date  total_cases  total_deaths  population
# 600299  Western Sahara 2022-04-20          NaN           NaN    568746.0
# 125243   Cote d'Ivoire 2023-02-19          NaN           NaN  30395004.0
# 319492           Macao 2023-12-31          NaN           NaN    704360.0
# 550435    Transnistria 2023-12-31          NaN           NaN         NaN
# 242842       Hong Kong 2024-08-12          NaN           NaN   7465913.0

# %%
top_cases_countries = (
    latest_country_data
    .sort_values(
        "total_cases",
        ascending=False
    )
    .head(15)
)

top_cases_countries[
    [
        "country",
        "total_cases",
        "total_deaths"
    ]
]
# Out:
#                     country  total_cases  total_deaths
# 603071                World  779277425.0     7115706.0
# 31623                  Asia  302281530.0     1637916.0
# 175482               Europe  254969570.0     2111788.0
# 177913  European Union (27)  186989386.0     1271086.0
# 397347        North America  124524251.0     1717813.0
# 577203        United States  103436829.0     1239049.0
# 111933                China   99381761.0      122398.0
# 511969        South America   69404861.0     1356731.0
# 250144                India   45056221.0      533849.0
# 190080               France   39061500.0      168207.0
# 204678              Germany   38437953.0      174979.0
# 77863                Brazil   38050567.0      704066.0
# 514403          South Korea   34571873.0       35934.0
# 272047                Japan   33803572.0       74694.0
# 267179                Italy   26969918.0      198523.0

# %%
plt.figure(figsize=(12, 7))

sns.barplot(
    data=top_cases_countries,
    x="total_cases",
    y="country"
)

plt.title("Top 15 Countries by Reported Total COVID-19 Cases")
plt.xlabel("Total Cases")
plt.ylabel("Country")

plt.tight_layout()
plt.show()

# %%
top_death_countries = (
    latest_country_data
    .sort_values(
        "total_deaths",
        ascending=False
    )
    .head(15)
)

top_death_countries[
    [
        "country",
        "total_deaths",
        "total_cases"
    ]
]
# Out:
#                     country  total_deaths  total_cases
# 603071                World     7115706.0  779277425.0
# 175482               Europe     2111788.0  254969570.0
# 397347        North America     1717813.0  124524251.0
# 31623                  Asia     1637916.0  302281530.0
# 511969        South America     1356731.0   69404861.0
# 177913  European Union (27)     1271086.0  186989386.0
# 577203        United States     1239049.0  103436829.0
# 77863                Brazil      704066.0   38050567.0
# 250144                India      533849.0   45056221.0
# 452259               Russia      404290.0   24901467.0
# 348688               Mexico      335153.0    7632101.0
# 4864                 Africa      258288.0   13064432.0
# 574769       United Kingdom      232112.0   25122084.0
# 430359                 Peru      221072.0    4533862.0
# 267179                Italy      198523.0   26969918.0

# %%
plt.figure(figsize=(12, 7))

sns.barplot(
    data=top_death_countries,
    x="total_deaths",
    y="country"
)

plt.title("Top 15 Countries by Reported COVID-19 Deaths")
plt.xlabel("Total Deaths")
plt.ylabel("Country")

plt.tight_layout()
plt.show()

# %%
top_cases_per_million = (
    latest_country_data
    .sort_values(
        "total_cases_per_million",
        ascending=False
    )
    .head(15)
)

top_cases_per_million[
    [
        "country",
        "total_cases_per_million",
        "population"
    ]
]
# Out:
#                           country  total_cases_per_million  population
# 82728                      Brunei                769806.80    455374.0
# 134976                     Cyprus                764573.94   1331376.0
# 476575                 San Marino                741418.25     34113.0
# 38922                     Austria                671154.10   9064678.0
# 514403                South Korea                667636.06  51782515.0
# 338955                 Martinique                659167.50    349462.0
# 502236                   Slovenia                646234.40   2115231.0
# 274478                     Jersey                641502.30    103493.0
# 182778              Faroe Islands                641351.60     54039.0
# 318284                 Luxembourg                614902.44    653315.0
# 190080                     France                607701.80  66277412.0
# 14597                     Andorra                602280.44     79722.0
# ...

# %%
plt.figure(figsize=(12, 7))

sns.barplot(
    data=top_cases_per_million,
    x="total_cases_per_million",
    y="country"
)

plt.title(
    "Top 15 Countries by COVID-19 Cases per Million"
)

plt.xlabel("Cases per Million")
plt.ylabel("Country")

plt.tight_layout()
plt.show()

# %%
pakistan = df_countries[
    df_countries["country"] == "Pakistan"
].copy()

print("Pakistan rows:", len(pakistan))
print(
    "Pakistan date range:",
    pakistan["date"].min(),
    "to",
    pakistan["date"].max()
)
# Out:
# Pakistan rows: 2434
# Pakistan date range: 2020-01-01 00:00:00 to 2026-08-30 00:00:00

# %%
pakistan[
    [
        "date",
        "new_cases",
        "new_deaths",
        "total_cases",
        "total_deaths"
    ]
].tail()
# Out:
#              date  new_cases  new_deaths  total_cases  total_deaths
# 415754 2026-08-26        0.0         0.0    1580631.0       30656.0
# 415755 2026-08-27        0.0         0.0    1580631.0       30656.0
# 415756 2026-08-28        0.0         0.0    1580631.0       30656.0
# 415757 2026-08-29        0.0         0.0    1580631.0       30656.0
# 415758 2026-08-30        0.0         0.0    1580631.0       30656.0

# %%
plt.figure(figsize=(15, 6))

plt.plot(
    pakistan["date"],
    pakistan["new_cases"]
)

plt.title("Pakistan — Daily New COVID-19 Cases")
plt.xlabel("Date")
plt.ylabel("New Cases")

plt.tight_layout()
plt.show()

# %%
pakistan["cases_7day_avg"] = (
    pakistan["new_cases"]
    .rolling(7)
    .mean()
)

plt.figure(figsize=(15, 6))

plt.plot(
    pakistan["date"],
    pakistan["cases_7day_avg"]
)

plt.title(
    "Pakistan — Daily COVID-19 Cases (7-Day Moving Average)"
)

plt.xlabel("Date")
plt.ylabel("7-Day Average")

plt.tight_layout()
plt.show()

# %%
latest_country_data["case_fatality_rate"] = (
    latest_country_data["total_deaths"]
    / latest_country_data["total_cases"]
) * 100

# %%
latest_country_data[
    [
        "country",
        "total_cases",
        "total_deaths",
        "case_fatality_rate"
    ]
].head(20)
# Out:
#                      country  total_cases  total_deaths  case_fatality_rate
# 600299        Western Sahara          NaN           NaN                 NaN
# 125243         Cote d'Ivoire          NaN           NaN                 NaN
# 319492                 Macao          NaN           NaN                 NaN
# 550435          Transnistria          NaN           NaN                 NaN
# 242842             Hong Kong          NaN           NaN                 NaN
# 535786                Taiwan          NaN           NaN                 NaN
# 26758                Armenia     454904.0        8785.0            1.931177
# 36488              Australia   11861161.0       25236.0            0.212762
# 41356             Azerbaijan     836510.0       10353.0            1.237642
# 343823             Mauritius     332300.0        1074.0            0.323202
# 209543             Gibraltar      20550.0         113.0            0.549878
# ...

# %%
latest_country_data["case_fatality_rate"] = np.where(
    latest_country_data["total_cases"] > 0,
    (latest_country_data["total_deaths"] /
     latest_country_data["total_cases"]) * 100,
    np.nan
)

# %%
top_cfr = (
    latest_country_data[
        latest_country_data["total_cases"] >= 10000
    ]
    .sort_values(
        "case_fatality_rate",
        ascending=False
    )
    .head(15)
)

top_cfr[
    [
        "country",
        "total_cases",
        "total_deaths",
        "case_fatality_rate"
    ]
]
# Out:
#                        country  total_cases  total_deaths  case_fatality_rate
# 612798                   Yemen      11945.0        2159.0           18.074508
# 524139                   Sudan      63993.0        5046.0            7.885237
# 534400                   Syria      57423.0        3163.0            5.508246
# 507104                 Somalia      27334.0        1361.0            4.979147
# 430359                    Peru    4533862.0      221072.0            4.876020
# 156882                   Egypt     516023.0       24830.0            4.811801
# 348688                  Mexico    7632101.0      335153.0            4.391360
# 72995   Bosnia and Herzegovina     404289.0       16419.0            4.061204
# 2433               Afghanistan     235214.0        7998.0            3.400308
# 154448                 Ecuador    1082356.0       36064.0            3.331991
# 370585                 Myanmar     643401.0       19494.0            3.029837
# ...

# %%
plt.figure(figsize=(12, 7))

sns.barplot(
    data=top_cfr,
    x="case_fatality_rate",
    y="country"
)

plt.title("Countries with Highest Reported COVID-19 Case Fatality Rate")
plt.xlabel("Case Fatality Rate (%)")
plt.ylabel("Country")

plt.tight_layout()
plt.show()

# %%
pakistan_latest = (
    pakistan
    .sort_values("date")
    .iloc[-1]
)

pakistan_cfr = (
    pakistan_latest["total_deaths"]
    / pakistan_latest["total_cases"]
) * 100

print("Pakistan reported CFR:",
      round(pakistan_cfr, 2), "%")
# Out:
# Pakistan reported CFR: 1.94 %

# %%
plt.figure(figsize=(15, 6))

plt.plot(
    pakistan["date"],
    pakistan["total_cases"]
)

plt.title("Pakistan — Cumulative COVID-19 Cases")
plt.xlabel("Date")
plt.ylabel("Total Cases")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 6))

plt.plot(
    pakistan["date"],
    pakistan["total_deaths"]
)

plt.title("Pakistan — Cumulative COVID-19 Deaths")
plt.xlabel("Date")
plt.ylabel("Total Deaths")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 7))

sns.scatterplot(
    data=latest_country_data,
    x="total_cases",
    y="total_deaths"
)

plt.title("COVID-19 Total Cases vs Total Deaths")
plt.xlabel("Total Cases")
plt.ylabel("Total Deaths")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 7))

sns.scatterplot(
    data=latest_country_data,
    x="total_cases",
    y="total_deaths"
)

plt.xscale("log")
plt.yscale("log")

plt.title("COVID-19 Cases vs Deaths — Log Scale")
plt.xlabel("Total Cases (log scale)")
plt.ylabel("Total Deaths (log scale)")

plt.tight_layout()
plt.show()

# %%
global_daily["month"] = (
    global_daily["date"]
    .dt.to_period("M")
)

# %%
monthly_global = (
    global_daily
    .groupby("month", as_index=False)
    .agg({
        "new_cases": "sum",
        "new_deaths": "sum"
    })
)

# %%
plt.figure(figsize=(16, 6))

plt.plot(
    monthly_global["month"].astype(str),
    monthly_global["new_cases"]
)

plt.title("Monthly Global Reported COVID-19 Cases")
plt.xlabel("Month")
plt.ylabel("Reported New Cases")

plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(16, 6))

plt.plot(
    monthly_global["month"].astype(str),
    monthly_global["new_deaths"]
)

plt.title("Monthly Global Reported COVID-19 Deaths")
plt.xlabel("Month")
plt.ylabel("Reported New Deaths")

plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %%
top_global_months = (
    monthly_global
    .sort_values(
        "new_cases",
        ascending=False
    )
    .head(10)
)

top_global_months
# Out:
#       month    new_cases  new_deaths
# 24  2022-01  308284880.0    801594.0
# 35  2022-12  276775508.0    256432.0
# 25  2022-02  197659931.0    896111.0
# 26  2022-03  162933863.0    590021.0
# 30  2022-07  105277931.0    225217.0
# 27  2022-04   87116015.0    277535.0
# 23  2021-12   78643083.0    702787.0
# 31  2022-08   77398703.0    225800.0
# 36  2023-01   70695484.0    200601.0
# 15  2021-04   69657798.0   1181723.0

# %%
top_global_death_months = (
    monthly_global
    .sort_values(
        "new_deaths",
        ascending=False
    )
    .head(10)
)

top_global_death_months
# Out:
#       month    new_cases  new_deaths
# 12  2021-01   64529272.0   1447717.0
# 16  2021-05   63572733.0   1201125.0
# 11  2020-12   60034777.0   1192425.0
# 15  2021-04   69657798.0   1181723.0
# 10  2020-11   58798339.0   1001509.0
# 13  2021-02   35677210.0    975652.0
# 19  2021-08   62407474.0    936043.0
# 14  2021-03   46515635.0    899436.0
# 25  2022-02  197659931.0    896111.0
# 17  2021-06   34692787.0    817714.0

# %%
pakistan["month"] = (
    pakistan["date"]
    .dt.to_period("M")
)

# %%
pakistan_monthly = (
    pakistan
    .groupby("month", as_index=False)
    .agg({
        "new_cases": "sum",
        "new_deaths": "sum"
    })
)

# %%
plt.figure(figsize=(16, 6))

plt.plot(
    pakistan_monthly["month"].astype(str),
    pakistan_monthly["new_cases"]
)

plt.title("Pakistan — Monthly Reported COVID-19 Cases")
plt.xlabel("Month")
plt.ylabel("New Cases")

plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %%
pakistan_peak_months = (
    pakistan_monthly
    .sort_values(
        "new_cases",
        ascending=False
    )
    .head(10)
)

pakistan_peak_months
# Out:
#       month  new_cases  new_deaths
# 15  2021-04   152511.0      3324.0
# 5   2020-06   140055.0      2772.0
# 19  2021-08   131420.0      2375.0
# 24  2022-01   123130.0       327.0
# 16  2021-05   103225.0      3056.0
# 25  2022-02    90513.0       925.0
# 20  2021-09    87104.0      2020.0
# 14  2021-03    84403.0      1519.0
# 11  2020-12    82055.0      2062.0
# 6   2020-07    70890.0      1757.0

# %%
pakistan_peak_death_months = (
    pakistan_monthly
    .sort_values(
        "new_deaths",
        ascending=False
    )
    .head(10)
)

pakistan_peak_death_months
# Out:
#       month  new_cases  new_deaths
# 15  2021-04   152511.0      3324.0
# 16  2021-05   103225.0      3056.0
# 5   2020-06   140055.0      2772.0
# 19  2021-08   131420.0      2375.0
# 11  2020-12    82055.0      2062.0
# 20  2021-09    87104.0      2020.0
# 6   2020-07    70890.0      1757.0
# 12  2021-01    65974.0      1576.0
# 14  2021-03    84403.0      1519.0
# 17  2021-06    37456.0      1518.0

# %%
pakistan["cases_7day_avg"] = (
    pakistan["new_cases"]
    .rolling(window=7)
    .mean()
)

pakistan["deaths_7day_avg"] = (
    pakistan["new_deaths"]
    .rolling(window=7)
    .mean()
)

# %%
plt.figure(figsize=(15, 6))

plt.plot(
    pakistan["date"],
    pakistan["cases_7day_avg"]
)

plt.title(
    "Pakistan — COVID-19 Cases (7-Day Moving Average)"
)

plt.xlabel("Date")
plt.ylabel("7-Day Average New Cases")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 6))

plt.plot(
    pakistan["date"],
    pakistan["deaths_7day_avg"]
)

plt.title(
    "Pakistan — COVID-19 Deaths (7-Day Moving Average)"
)

plt.xlabel("Date")
plt.ylabel("7-Day Average New Deaths")

plt.tight_layout()
plt.show()

# %%
latest_testing = (
    df_countries
    .sort_values("date")
    .groupby("country")
    .tail(1)
    .copy()
)

latest_testing[
    [
        "country",
        "total_tests",
        "total_tests_per_thousand",
        "positive_rate",
        "tests_per_case"
    ]
].head(20)
# Out:
#                      country  total_tests  total_tests_per_thousand  \
# 600299        Western Sahara       3943.0                     6.972
# 125243         Cote d'Ivoire          NaN                       NaN
# 319492                 Macao          NaN                       NaN
# 550435          Transnistria          NaN                       NaN
# 242842             Hong Kong          NaN                       NaN
# 535786                Taiwan          NaN                       NaN
# 26758                Armenia          NaN                       NaN
# 36488              Australia          NaN                       NaN
# 41356             Azerbaijan          NaN                       NaN
# 343823             Mauritius          NaN                       NaN
# 209543             Gibraltar          NaN                       NaN
# 221707                  Guam          NaN                       NaN
# 360852            Montenegro          NaN                       NaN
# ...

# %%
latest_testing = (
    df_countries
    .sort_values("date")
    .groupby("country")
    .tail(1)
    .copy()
)

latest_testing[
    [
        "country",
        "total_tests",
        "total_tests_per_thousand",
        "positive_rate",
        "tests_per_case"
    ]
].head(20)
# Out:
#                      country  total_tests  total_tests_per_thousand  \
# 600299        Western Sahara       3943.0                     6.972
# 125243         Cote d'Ivoire          NaN                       NaN
# 319492                 Macao          NaN                       NaN
# 550435          Transnistria          NaN                       NaN
# 242842             Hong Kong          NaN                       NaN
# 535786                Taiwan          NaN                       NaN
# 26758                Armenia          NaN                       NaN
# 36488              Australia          NaN                       NaN
# 41356             Azerbaijan          NaN                       NaN
# 343823             Mauritius          NaN                       NaN
# 209543             Gibraltar          NaN                       NaN
# 221707                  Guam          NaN                       NaN
# 360852            Montenegro          NaN                       NaN
# ...

# %%
top_testing = (
    latest_testing
    .dropna(subset=["total_tests"])
    .sort_values(
        "total_tests",
        ascending=False
    )
    .head(15)
)

top_testing[
    [
        "country",
        "total_tests",
        "total_tests_per_thousand"
    ]
]
# Out:
#                country  total_tests  total_tests_per_thousand
# 600299  Western Sahara       3943.0                     6.972

# %%
plt.figure(figsize=(12, 7))

sns.barplot(
    data=top_testing,
    x="total_tests",
    y="country"
)

plt.title("Top 15 Countries by Total COVID-19 Tests")
plt.xlabel("Total Tests")
plt.ylabel("Country")

plt.tight_layout()
plt.show()

# %%
top_testing_rate = (
    latest_testing
    .dropna(subset=["total_tests_per_thousand"])
    .sort_values(
        "total_tests_per_thousand",
        ascending=False
    )
    .head(15)
)

top_testing_rate[
    [
        "country",
        "total_tests_per_thousand"
    ]
]
# Out:
#                country  total_tests_per_thousand
# 600299  Western Sahara                     6.972

# %%
plt.figure(figsize=(12, 7))

sns.barplot(
    data=top_testing_rate,
    x="total_tests_per_thousand",
    y="country"
)

plt.title("Top 15 Countries by COVID-19 Tests per Thousand People")
plt.xlabel("Tests per Thousand")
plt.ylabel("Country")

plt.tight_layout()
plt.show()

# %%
positive_rate_data = (
    latest_testing
    .dropna(subset=["positive_rate"])
    .sort_values(
        "positive_rate",
        ascending=False
    )
)

positive_rate_data[
    [
        "country",
        "positive_rate"
    ]
].head(15)
# Out:
# Empty DataFrame
# Columns: [country, positive_rate]
# Index: []

# %%
top_positive_rate = positive_rate_data.head(15)

plt.figure(figsize=(12, 7))

sns.barplot(
    data=top_positive_rate,
    x="positive_rate",
    y="country"
)

plt.title("Countries with Highest Reported COVID-19 Positive Rate")
plt.xlabel("Positive Rate")
plt.ylabel("Country")

plt.tight_layout()
plt.show()

# %%
pakistan_testing = pakistan[
    [
        "date",
        "total_tests",
        "new_tests",
        "positive_rate",
        "tests_per_case"
    ]
].copy()

pakistan_testing.tail()
# Out:
#              date  total_tests  new_tests  positive_rate  tests_per_case
# 415754 2026-08-26          NaN        NaN            NaN             NaN
# 415755 2026-08-27          NaN        NaN            NaN             NaN
# 415756 2026-08-28          NaN        NaN            NaN             NaN
# 415757 2026-08-29          NaN        NaN            NaN             NaN
# 415758 2026-08-30          NaN        NaN            NaN             NaN

# %%
plt.figure(figsize=(15, 6))

plt.plot(
    pakistan["date"],
    pakistan["total_tests"]
)

plt.title("Pakistan — Cumulative COVID-19 Tests")
plt.xlabel("Date")
plt.ylabel("Total Tests")

plt.tight_layout()
plt.show()

# %%
vaccination_data = latest_country_data[
    [
        "country",
        "date",
        "population",
        "total_vaccinations",
        "people_vaccinated",
        "people_fully_vaccinated",
        "total_boosters",
        "people_vaccinated_per_hundred",
        "people_fully_vaccinated_per_hundred"
    ]
].copy()

vaccination_data.head()
# Out:
#                country       date  population  total_vaccinations  \
# 600299  Western Sahara 2022-04-20    568746.0                 NaN
# 125243   Cote d'Ivoire 2023-02-19  30395004.0          25263932.0
# 319492           Macao 2023-12-31    704360.0                 NaN
# 550435    Transnistria 2023-12-31         NaN                 NaN
# 242842       Hong Kong 2024-08-12   7465913.0                 NaN
#
#         people_vaccinated  people_fully_vaccinated  total_boosters  \
# 600299                NaN                      NaN             NaN
# 125243         13568372.0               12164304.0       3138712.0
# 319492                NaN                      NaN             NaN
# 550435                NaN                      NaN             NaN
# 242842                NaN                      NaN             NaN
#
#         people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred
# 600299                            NaN                                  NaN
# ...

# %%
top_vaccinated = (
    vaccination_data
    .dropna(subset=["people_vaccinated_per_hundred"])
    .sort_values(
        "people_vaccinated_per_hundred",
        ascending=False
    )
    .head(15)
)

top_vaccinated[
    [
        "country",
        "people_vaccinated_per_hundred"
    ]
]
# Out:
#               country  people_vaccinated_per_hundred
# 125243  Cote d'Ivoire                       44.64014

# %%
plt.figure(figsize=(12, 7))

sns.barplot(
    data=top_vaccinated,
    x="people_vaccinated_per_hundred",
    y="country"
)

plt.title("Top 15 Countries by People Vaccinated (%)")
plt.xlabel("People Vaccinated (%)")
plt.ylabel("Country")

plt.tight_layout()
plt.show()

# %%
top_fully_vaccinated = (
    vaccination_data
    .dropna(subset=["people_fully_vaccinated_per_hundred"])
    .sort_values(
        "people_fully_vaccinated_per_hundred",
        ascending=False
    )
    .head(15)
)

top_fully_vaccinated[
    [
        "country",
        "people_fully_vaccinated_per_hundred"
    ]
]
# Out:
#               country  people_fully_vaccinated_per_hundred
# 125243  Cote d'Ivoire                            40.020737

# %%
plt.figure(figsize=(12, 7))

sns.barplot(
    data=top_fully_vaccinated,
    x="people_fully_vaccinated_per_hundred",
    y="country"
)

plt.title("Top 15 Countries by Fully Vaccinated Population (%)")
plt.xlabel("Fully Vaccinated (%)")
plt.ylabel("Country")

plt.tight_layout()
plt.show()

# %%
pakistan_vaccination = pakistan[
    [
        "date",
        "total_vaccinations",
        "people_vaccinated",
        "people_fully_vaccinated",
        "total_boosters",
        "people_vaccinated_per_hundred",
        "people_fully_vaccinated_per_hundred"
    ]
].copy()

pakistan_vaccination.tail()
# Out:
#              date  total_vaccinations  people_vaccinated  \
# 415754 2026-08-26                 NaN                NaN
# 415755 2026-08-27                 NaN                NaN
# 415756 2026-08-28                 NaN                NaN
# 415757 2026-08-29                 NaN                NaN
# 415758 2026-08-30                 NaN                NaN
#
#         people_fully_vaccinated  total_boosters  \
# 415754                      NaN             NaN
# 415755                      NaN             NaN
# 415756                      NaN             NaN
# 415757                      NaN             NaN
# 415758                      NaN             NaN
#
#         people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred
# 415754                            NaN                                  NaN
# 415755                            NaN                                  NaN
# 415756                            NaN                                  NaN
# ...

# %%
plt.figure(figsize=(15, 6))

plt.plot(
    pakistan_vaccination["date"],
    pakistan_vaccination["people_vaccinated_per_hundred"]
)

plt.title(
    "Pakistan — Population with at Least One COVID-19 Vaccine Dose"
)

plt.xlabel("Date")
plt.ylabel("People Vaccinated (%)")

plt.tight_layout()
plt.show()

# %%
vaccination_data = latest_country_data[
    [
        "country",
        "date",
        "population",
        "total_vaccinations",
        "people_vaccinated",
        "people_fully_vaccinated",
        "total_boosters",
        "people_vaccinated_per_hundred",
        "people_fully_vaccinated_per_hundred"
    ]
].copy()

vaccination_data.head()
# Out:
#                country       date  population  total_vaccinations  \
# 600299  Western Sahara 2022-04-20    568746.0                 NaN
# 125243   Cote d'Ivoire 2023-02-19  30395004.0          25263932.0
# 319492           Macao 2023-12-31    704360.0                 NaN
# 550435    Transnistria 2023-12-31         NaN                 NaN
# 242842       Hong Kong 2024-08-12   7465913.0                 NaN
#
#         people_vaccinated  people_fully_vaccinated  total_boosters  \
# 600299                NaN                      NaN             NaN
# 125243         13568372.0               12164304.0       3138712.0
# 319492                NaN                      NaN             NaN
# 550435                NaN                      NaN             NaN
# 242842                NaN                      NaN             NaN
#
#         people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred
# 600299                            NaN                                  NaN
# ...

# %%
top_vaccinated = (
    vaccination_data
    .dropna(subset=["people_vaccinated_per_hundred"])
    .sort_values(
        "people_vaccinated_per_hundred",
        ascending=False
    )
    .head(15)
)

top_vaccinated[
    [
        "country",
        "people_vaccinated_per_hundred"
    ]
]
# Out:
#               country  people_vaccinated_per_hundred
# 125243  Cote d'Ivoire                       44.64014

# %%
plt.figure(figsize=(12, 7))

sns.barplot(
    data=top_vaccinated,
    x="people_vaccinated_per_hundred",
    y="country"
)

plt.title("Top 15 Countries by People Vaccinated (%)")
plt.xlabel("People Vaccinated (%)")
plt.ylabel("Country")

plt.tight_layout()
plt.show()

# %%
top_fully_vaccinated = (
    vaccination_data
    .dropna(subset=["people_fully_vaccinated_per_hundred"])
    .sort_values(
        "people_fully_vaccinated_per_hundred",
        ascending=False
    )
    .head(15)
)

top_fully_vaccinated[
    [
        "country",
        "people_fully_vaccinated_per_hundred"
    ]
]
# Out:
#               country  people_fully_vaccinated_per_hundred
# 125243  Cote d'Ivoire                            40.020737

# %%
plt.figure(figsize=(12, 7))

sns.barplot(
    data=top_fully_vaccinated,
    x="people_fully_vaccinated_per_hundred",
    y="country"
)

plt.title("Top 15 Countries by Fully Vaccinated Population (%)")
plt.xlabel("Fully Vaccinated (%)")
plt.ylabel("Country")

plt.tight_layout()
plt.show()

# %%
pakistan_vaccination = pakistan[
    [
        "date",
        "total_vaccinations",
        "people_vaccinated",
        "people_fully_vaccinated",
        "total_boosters",
        "people_vaccinated_per_hundred",
        "people_fully_vaccinated_per_hundred"
    ]
].copy()

pakistan_vaccination.tail()
# Out:
#              date  total_vaccinations  people_vaccinated  \
# 415754 2026-08-26                 NaN                NaN
# 415755 2026-08-27                 NaN                NaN
# 415756 2026-08-28                 NaN                NaN
# 415757 2026-08-29                 NaN                NaN
# 415758 2026-08-30                 NaN                NaN
#
#         people_fully_vaccinated  total_boosters  \
# 415754                      NaN             NaN
# 415755                      NaN             NaN
# 415756                      NaN             NaN
# 415757                      NaN             NaN
# 415758                      NaN             NaN
#
#         people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred
# 415754                            NaN                                  NaN
# 415755                            NaN                                  NaN
# 415756                            NaN                                  NaN
# ...

# %%
plt.figure(figsize=(15, 6))

plt.plot(
    pakistan_vaccination["date"],
    pakistan_vaccination["people_vaccinated_per_hundred"]
)

plt.title(
    "Pakistan — Population with at Least One COVID-19 Vaccine Dose"
)

plt.xlabel("Date")
plt.ylabel("People Vaccinated (%)")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 6))

plt.plot(
    pakistan_vaccination["date"],
    pakistan_vaccination["people_fully_vaccinated_per_hundred"]
)

plt.title(
    "Pakistan — Fully Vaccinated Population Over Time"
)

plt.xlabel("Date")
plt.ylabel("Fully Vaccinated (%)")

plt.tight_layout()
plt.show()

# %%
analysis_columns = [
    "total_cases_per_million",
    "total_deaths_per_million",
    "total_tests_per_thousand",
    "people_vaccinated_per_hundred",
    "people_fully_vaccinated_per_hundred",
    "population_density",
    "median_age",
    "life_expectancy",
    "gdp_per_capita",
    "diabetes_prevalence"
]

analysis_data = latest_country_data[
    analysis_columns
].copy()

analysis_data.head()
# Out:
#         total_cases_per_million  total_deaths_per_million  \
# 600299                      NaN                       NaN
# 125243                      NaN                       NaN
# 319492                      NaN                       NaN
# 550435                      NaN                       NaN
# 242842                      NaN                       NaN
#
#         total_tests_per_thousand  people_vaccinated_per_hundred  \
# 600299                     6.972                            NaN
# 125243                       NaN                       44.64014
# 319492                       NaN                            NaN
# 550435                       NaN                            NaN
# 242842                       NaN                            NaN
#
#         people_fully_vaccinated_per_hundred  population_density  median_age  \
# 600299                                  NaN            2.138143   31.698000
# ...

# %%
correlation_matrix = analysis_data.corr()

correlation_matrix
# Out:
#                                      total_cases_per_million  \
# total_cases_per_million                             1.000000
# total_deaths_per_million                            0.433860
# total_tests_per_thousand                                 NaN
# people_vaccinated_per_hundred                            NaN
# people_fully_vaccinated_per_hundred                      NaN
# population_density                                  0.154737
# median_age                                          0.708058
# life_expectancy                                     0.619045
# gdp_per_capita                                      0.698667
# diabetes_prevalence                                 0.011060
#
#                                      total_deaths_per_million  \
# total_cases_per_million                              0.433860
# total_deaths_per_million                             1.000000
# total_tests_per_thousand                                  NaN
# ...

# %%
plt.figure(figsize=(12, 9))

sns.heatmap(
    correlation_matrix,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    center=0
)

plt.title("Correlation Matrix of Selected COVID-19 Variables")

plt.tight_layout()
plt.show()

# %%
cases_deaths_corr = (
    latest_country_data[
        [
            "total_cases_per_million",
            "total_deaths_per_million"
        ]
    ]
    .corr()
)

cases_deaths_corr
# Out:
#                           total_cases_per_million  total_deaths_per_million
# total_cases_per_million                   1.00000                   0.43386
# total_deaths_per_million                  0.43386                   1.00000

# %%
correlation_value = (
    latest_country_data[
        [
            "total_cases_per_million",
            "total_deaths_per_million"
        ]
    ]
    .corr()
    .iloc[0, 1]
)

print(
    "Correlation between cases per million and deaths per million:",
    round(correlation_value, 3)
)
# Out:
# Correlation between cases per million and deaths per million: 0.434

# %%
vaccination_death_data = latest_country_data[
    [
        "people_fully_vaccinated_per_hundred",
        "total_deaths_per_million"
    ]
].dropna()

vaccination_death_corr = (
    vaccination_death_data
    .corr()
    .iloc[0, 1]
)

print(
    "Correlation between full vaccination (%) and deaths per million:",
    round(vaccination_death_corr, 3)
)
# Out:
# Correlation between full vaccination (%) and deaths per million: nan

# %%
vaccination_case_data = latest_country_data[
    [
        "people_fully_vaccinated_per_hundred",
        "total_cases_per_million"
    ]
].dropna()

vaccination_case_corr = (
    vaccination_case_data
    .corr()
    .iloc[0, 1]
)

print(
    "Correlation between full vaccination (%) and cases per million:",
    round(vaccination_case_corr, 3)
)
# Out:
# Correlation between full vaccination (%) and cases per million: nan

# %%
final_summary = pd.DataFrame({
    "Metric": [
        "Total Observations",
        "Countries/Entities",
        "Start Date",
        "End Date",
        "Duplicate Rows",
        "Duplicate Country-Date Pairs",
        "Peak Daily Global Cases",
        "Peak Daily Global Deaths",
        "Pakistan Total Cases",
        "Pakistan Total Deaths",
        "Pakistan CFR (%)"
    ],
    "Value": [
        len(df_clean),
        df_countries["country"].nunique(),
        df_clean["date"].min(),
        df_clean["date"].max(),
        df_clean.duplicated().sum(),
        df_clean.duplicated(
            subset=["country", "date"]
        ).sum(),
        global_daily["new_cases"].max(),
        global_daily["new_deaths"].max(),
        pakistan_latest["total_cases"],
        pakistan_latest["total_deaths"],
        round(pakistan_cfr, 2)
    ]
})

final_summary
# Out:
#                           Metric                Value
# 0             Total Observations               617667
# 1             Countries/Entities                  247
# 2                     Start Date  2020-01-01 00:00:00
# 3                       End Date  2026-08-30 00:00:00
# 4                 Duplicate Rows                    0
# 5   Duplicate Country-Date Pairs                    0
# 6        Peak Daily Global Cases           31101814.0
# 7       Peak Daily Global Deaths             171685.0
# 8           Pakistan Total Cases            1580631.0
# 9          Pakistan Total Deaths              30656.0
# 10              Pakistan CFR (%)                 1.94
